# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('travel.csv')

# %%
df1 = pd.read_csv('sci.csv')

# %%
df2=df.append(df1)

# %%
df3 = pd.read_csv('food.csv')

# %%
df4 = pd.read_csv('manufacturing.csv')

# %%
df5 = df2.append(df3)

# %%
df6 = df5.append(df4)

# %%
df7 = pd.read_csv('history.csv')

# %%
df8 = df6.append(df7)

# %%
df9 = pd.read_csv('art.csv')

# %%
df10 = df8.append(df9)

# %%
df10
# Out:
#          Video ID                                              Title  \
# 0     YIhcFd49_ik  TRAVEL HACKS THAT WILL DIVIDE YOUR LIFE INTO B...
# 1     ehmsJLZlCZ0  Ep 1| Travelling through North East India | Of...
# 2     e2NQE41J5eM    How do I travel so much ! How do I earn money!!
# 3     RcmrbNRK-jY     200 Days - A Trip Around the World Travel Film
# 4     4Z72A515cxw  FOREIGNER TRAVEL IN INDIA: more BIG mistakes N...
# 5     ZoJhZITuLRQ                          33 WAYS TO TRAVEL SMARTER
# 6     4ugTghplpLU          Avengers: Endgame - Time Travel Explained
# 7     fCA30WAYprA  Barbie &amp; Chelsea Airplane Travel Trouble! ...
# 8     Z2TvyOYSb-U  7 Cheapest Countries in the World to travel - ...
# 9     Df_S4Fuce_4                         Newborn Travel Tips | Vlog
# 10    KCAFyJ29HTs          Travel with me to India! Delhi &amp; Agra
# 11    lJ87yD_8u3U  Top 7 INCREDIBLE Travel Destinations of 2019 |...
# 12    zLF9oGAM2WU  Avengers Endgame&#39;s Confusing Plot Explaine...
# ...

# %%
count = 0
for category in df10['Category']:
    if category == 'travel':
        count+=1

# %%
count
# Out:
# 1834

# %%
df_final = df10.sample(frac=1).reset_index(drop=True)

# %%
df_final
# Out:
#           Video ID                                              Title  \
# 0      aEHQLSPd-UU  DIY || Old bangles reuse idea  | Best craft id...
# 1      -Rulkhgrzf8  HSC Islamic History and Culture 2nd Paper MCQ ...
# 2      wnBYo8ecbnA  5 Giant DIY Foods Challenge &amp; How To Make ...
# 3      R7vmHGAshi8  How to travel the world with almost no money |...
# 4      ehmsJLZlCZ0  Ep 1| Travelling through North East India | Of...
# 5      DJUzVC2RE9c  #SCIENCE &amp; TECHNOLOGY #CURRENTAFFAIRS2018 ...
# 6      rjT1klsy-1c        Smart manufacturing of power semiconductors
# 7      owDDacaoOkY  Mumbai STREET Food Tour - Bombay Sandwich + Pa...
# 8      V-tFtSePByQ  Do You Know ! How Are Steel Pipes Produced | S...
# 9      QdwXMLJfGTc                       THIS ART BOX is INCREDIBLE!!
# 10     0XT93hNamn0  Unlimited Chole Bhature Eating Challenge | Hug...
# 11     -X1RHzKYGgY  Hong Kong Street Food. A Walk Around the Stall...
# ...

# %%
df_final.to_csv('YT_Data_AllCategory.csv',index=False)

# %%
df11 = pd.read_csv('YT_Data_AllCategory.csv')

# %%
df11
# Out:
#           Video ID                                              Title  \
# 0      aEHQLSPd-UU  DIY || Old bangles reuse idea  | Best craft id...
# 1      -Rulkhgrzf8  HSC Islamic History and Culture 2nd Paper MCQ ...
# 2      wnBYo8ecbnA  5 Giant DIY Foods Challenge &amp; How To Make ...
# 3      R7vmHGAshi8  How to travel the world with almost no money |...
# 4      ehmsJLZlCZ0  Ep 1| Travelling through North East India | Of...
# 5      DJUzVC2RE9c  #SCIENCE &amp; TECHNOLOGY #CURRENTAFFAIRS2018 ...
# 6      rjT1klsy-1c        Smart manufacturing of power semiconductors
# 7      owDDacaoOkY  Mumbai STREET Food Tour - Bombay Sandwich + Pa...
# 8      V-tFtSePByQ  Do You Know ! How Are Steel Pipes Produced | S...
# 9      QdwXMLJfGTc                       THIS ART BOX is INCREDIBLE!!
# 10     0XT93hNamn0  Unlimited Chole Bhature Eating Challenge | Hug...
# 11     -X1RHzKYGgY  Hong Kong Street Food. A Walk Around the Stall...
# ...
